# %%
from analysis import *

# %%
## Add a hf_token file include your huggieface token, which start with'hf_'
## Add the ZOD video data in the video file

## Change the query to define the scenario you want to search for
## Example: driving in a rainy day.
query = 'driving in a rainy day'

search(query)
# Out:
# The top 6 matching records are: 000277, 000775, 000278, 000776, 000249, 000907
# {'Largest Gap': 0.48257337510585785, 'Min Distance': 0.24946445226669312, 'Max Distance': 0.9078721851110458, 'Range': 0.6584077328443527, 'Standard Deviation': np.float64(0.07760864585034757), 'Relative Largest Gap': 0.7329400173067803}
